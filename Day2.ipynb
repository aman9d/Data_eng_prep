# %% [markdown]
# <a href="https://colab.research.google.com/github/aman9d/Data_eng_prep/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
city_dict= {'Pune':100,'Mumbai':150,'Delhi':200,'Jhansi':80,'Gwalior':90}
print('orignal city: ', city_dict)

city_dict['Jhansi']=200
print('updated city: ',city_dict)

city_dict['Noida']=120
print('new city: ',city_dict)

print(city_dict.get('Jhansi'))
print(city_dict.get('XYZ'))

city_dict.pop('Noida')
print('pop city: ',city_dict)
# Out:
# orignal city:  {'Pune': 100, 'Mumbai': 150, 'Delhi': 200, 'Jhansi': 80, 'Gwalior': 90}
# updated city:  {'Pune': 100, 'Mumbai': 150, 'Delhi': 200, 'Jhansi': 200, 'Gwalior': 90}
# new city:  {'Pune': 100, 'Mumbai': 150, 'Delhi': 200, 'Jhansi': 200, 'Gwalior': 90, 'Noida': 120}
# 200
# None
# pop city:  {'Pune': 100, 'Mumbai': 150, 'Delhi': 200, 'Jhansi': 200, 'Gwalior': 90}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
lst=[1,4,3,2,3,1,4,9,0]
print(lst)
lst_set=set(lst)
print(lst_set)

set_1={1,4,5,6}
comman=set_1.intersection(lst_set)
print(comman)

diff= set_1.difference(lst_set)
print(diff)
# Out:
# [1, 4, 3, 2, 3, 1, 4, 9, 0]
# {0, 1, 2, 3, 4, 9}
# {1, 4}
# {5, 6}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
result=[]
for i in range(1,11):
  if i%2==0:
    result.append(i*i)
print(result)
# Out:
# [4, 16, 36, 64, 100]

# %%
a=[i*i for i in range(1,11) if i %2==0]
print(a)
# Out:
# [4, 16, 36, 64, 100]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
nums1=[1,2,3]
nums2=[2,4,5]
l1_set=set(nums1)
l2_set=set(nums2)
l1_set.intersection(l2_set)
# Out:
# {2}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def singleNumber(nums):
        dict={}
        for i in nums:
            dict[i]=dict.get(i,0)+1

        for key, value in dict.items():
            if value<=1:
                return key

# %% [markdown]
# https://leetcode.com/problems/single-number-ii/description/
